# %%
import torch
from torch.func import hessian
from torch.func import jacrev
# I can not find a Newton solver in torch
# I am going to use one from scipy.
from scipy.optimize import fsolve

def f(x):
    """ Gen Rosenbrock function.
    Args: x (torch.Tensor): Input tensor of shape (n).
    Returns: torch.Tensor: Output tensor of shape (1).
    """
    return torch.sum(100.0 * (x[1:] - x[:-1]**2)**2 + (1 - x[:-1])**2, dim=-1)

x = torch.randn(4)
hess = hessian(f)(x)  # equivalent to jacfwd(jacrev(f))(x)

g = jacrev(f)(x)
# print(hess)
# print(g)


fsolve(jacrev(f),x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-56c4c418ad20> in <module>
#      15 # print(hess)
#      16 # print(g)
# ---> 17 fsolve(jacrev(f),x)
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#     161                'diag': diag}
#     162
# --> 163     res = _root_hybr(func, x0, args, jac=fprime, **options)
#     164     if full_output:
#     165         x = res['x']
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py in _root_hybr(func, x0, args, jac, col_deriv, xtol, maxfev, band, eps, factor, diag, **unknown_options)
#     227     if not isinstance(args, tuple):
#     228         args = (args,)
# --> 229     shape, dtype = _check_func('fsolve', 'func', func, x0, args, n, (n,))
#     230     if epsfcn is None:
#     231         epsfcn = finfo(dtype).eps
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      24 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      25                 output_shape=None):
# ---> 26     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      27     if (output_shape is not None) and (shape(res) != output_shape):
#      28         if (output_shape[0] != 1):
#
# ~\anaconda3\lib\site-packages\torch\_functorch\eager_transforms.py in wrapper_fn(*args)
#     603     def wrapper_fn(*args):
#     604         error_if_complex("jacrev", args, is_input=True)
# --> 605         vjp_out = _vjp_with_argnums(func, *args, argnums=argnums, has_aux=has_aux)
#     606         if has_aux:
#     607             output, vjp_fn, aux = vjp_out
#
# ~\anaconda3\lib\site-packages\torch\_functorch\vmap.py in fn(*args, **kwargs)
#      46     def fn(*args, **kwargs):
#      47         with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 48             return f(*args, **kwargs)
#      49
#      50     return fn
#
# ~\anaconda3\lib\site-packages\torch\_functorch\eager_transforms.py in _vjp_with_argnums(func, argnums, has_aux, *primals)
#     397             else:
#     398                 diff_primals = _slice_argnums(primals, argnums, as_tuple=False)
# --> 399                 tree_map_(partial(_create_differentiable, level=level), diff_primals)
#     400             primals_out = func(*primals)
#     401
#
# ~\anaconda3\lib\site-packages\torch\utils\_pytree.py in tree_map_(func, tree, is_leaf, *rests)
#     979     leaves, treespec = tree_flatten(tree, is_leaf=is_leaf)
#     980     flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 981     tuple(map(func, *flat_args))  # consume and exhaust the iterable
#     982     return tree
#     983
#
# ~\anaconda3\lib\site-packages\torch\_functorch\eager_transforms.py in _create_differentiable(inps, level)
#     118         )
#     119
# --> 120     return tree_map(create_differentiable, inps)
#     121
#     122
#
# ~\anaconda3\lib\site-packages\torch\utils\_pytree.py in tree_map(func, tree, is_leaf, *rests)
#     946     leaves, treespec = tree_flatten(tree, is_leaf=is_leaf)
#     947     flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 948     return treespec.unflatten(map(func, *flat_args))
#     949
#     950
#
# ~\anaconda3\lib\site-packages\torch\utils\_pytree.py in unflatten(self, leaves)
#     785     def unflatten(self, leaves: Iterable[Any]) -> PyTree:
#     786         if not isinstance(leaves, (list, tuple)):
# --> 787             leaves = list(leaves)
#     788         if len(leaves) != self.num_leaves:
#     789             raise ValueError(
#
# ~\anaconda3\lib\site-packages\torch\_functorch\eager_transforms.py in create_differentiable(x)
#     114             with enable_inplace_requires_grad(True):
#     115                 return _set_tensor_requires_grad(x)
# --> 116         raise ValueError(
#     117             f"Thing passed to transform API must be Tensor, " f"got {type(x)}"
#     118         )
#
# ValueError: Thing passed to transform API must be Tensor, got <class 'numpy.ndarray'>
